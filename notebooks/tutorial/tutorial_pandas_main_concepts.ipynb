# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/10min.html

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Helpers used throught code

# %%
def find_pandas_type(structure):
  if type(structure) is pd.Series:
    print('This is of type series')
  elif type(structure) is pd.DataFrame:
    print('This is of type dataframe')
  else:
    print('UNKOWN TYPE')

# %% [markdown]
# # Core Data Structures
#
# **1.) Series:**
# a one-dimensional labeled array holding data of any type
# such as integers, strings, Python objects etc.
#
# **2.) DataFrame:**
# a two-dimensional data structure that holds data like a two-dimension array or a table with rows and columns.

# %% [markdown]
# **1.) Series**
#
# https://pandas.pydata.org/docs/user_guide/dsintro.html#series

# %% [markdown]
# basic method to create a series:
#
# s = pd.Series(data, index=index)
#
# Here, data can be many different things:
# - List, tuple, or array-like
# - NumPy ndarray (np.array([1, 2, 3]))
#
# - Dictionary (Keys are used as index, values are used as data)
# - Scalar value, constant of certain type (index needs to be provided as parameter)
# - Existing pandas series(This creates a new series)

# %% [markdown]
# Default behavior for Index:
#
#  RangeIndex(start=0, stop=n, step=1) where n is the length of the Series.

# %%
ser1 = pd.Series([1, 3, 5, 6, 8])
ser1
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %% [markdown]
# By default index is create in range as if it were list index

# %%
ser1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ser1[2]
# Out:
# np.int64(5)

# %% [markdown]
# Mixed types get converted into objects

# %%
ser2 = pd.Series([1, 'v', '5', 6, 8])
ser2
# Out:
# 0    1
# 1    v
# 2    5
# 3    6
# 4    8
# dtype: object

# %% [markdown]
# You can also specifiy index of columns

# %%
ser3 = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
ser3
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser3.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
ser3['a'], ser3['b'], ser3['c']
# Out:
# (np.int64(10), np.int64(20), np.int64(30))

# %% [markdown]
# **How to reset index of series**

# %% [markdown]
# When you have custom index, you can reset index back to default range

# %%
series_custom_index = pd.Series([10, 20, 30], index=["a", "b", "c"], name="values")
series_custom_index
# Out:
# a    10
# b    20
# c    30
# Name: values, dtype: int64

# %% [markdown]
# Defult behavour when using reset_index, is that a new dataframe will be created, with the index as column.

# %%
out = series_custom_index.reset_index(drop=False)
out
# Out:
#   index  values
# 0     a      10
# 1     b      20
# 2     c      30

# %%
find_pandas_type(out)
# Out:
# This is of type dataframe

# %%
out['index']
# Out:
# 0    a
# 1    b
# 2    c
# Name: index, dtype: object

# %% [markdown]
# If you decide to drop the index a series is returned instead of dataframe.

# %%
out = series_custom_index.reset_index(drop=True)
out
# Out:
# 0    10
# 1    20
# 2    30
# Name: values, dtype: int64

# %%
find_pandas_type(out)
# Out:
# This is of type series

# %% [markdown]
# **Conversion of series to data frame**

# %%
ser4 = pd.Series([10, 20, 30], index=['a', 'b', 'c'])

# %%
df_from_series1 = ser4.to_frame()
df_from_series1
# Out:
#     0
# a  10
# b  20
# c  30

# %%
df_from_series2 = pd.DataFrame(ser4)
df_from_series2
# Out:
#     0
# a  10
# b  20
# c  30

# %% [markdown]
# **Index is added to dataframe as a column**

# %%
df_from_ser  = ser4.reset_index()

# %%
df_from_ser
# Out:
#   index   0
# 0     a  10
# 1     b  20
# 2     c  30

# %%
df_from_ser[0]
# Out:
# 0    10
# 1    20
# 2    30
# Name: 0, dtype: int64

# %% [markdown]
# **2.) Data Frame**
#
# https://pandas.pydata.org/docs/user_guide/dsintro.html#dataframe

# %% [markdown]
#  Example of creation of datafram from dictionary of objects, where key is column labels and values are column values**

# %%
# DataFrame
df = pd.DataFrame(
    {
        "A": list(range(4)),
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df
# Out:
#    A          B    C  D      E    F
# 0  0 2013-01-02  1.0  3   test  foo
# 1  1 2013-01-02  1.0  3  train  foo
# 2  2 2013-01-02  1.0  3   test  foo
# 3  3 2013-01-02  1.0  3  train  foo

# %%
df.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %% [markdown]
# Each column has its own separate type

# %%
df.dtypes
# Out:
# A            int64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# **Accesing columns via single or double brackets**

# %% [markdown]
# • 	Single brackets → Series
#
# • 	Double brackets → DataFrame

# %% [markdown]
# Accessed column from dataframe is a Series, when using single brackets.

# %%
df['A']
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# Name: A, dtype: int64

# %%
type(df['A']) is pd.Series
# Out:
# True

# %% [markdown]
# Accessed column from dataframe is a Dataframe, when using double brackets.

# %%
df[['A']]
# Out:
#    A
# 0  0
# 1  1
# 2  2
# 3  3

# %%
type(df[['A']]) is pd.DataFrame
# Out:
# True

# %% [markdown]
# # IO operations

# %% [markdown]
# **1.) Reading of dataframe from csv file**

# %% [markdown]
# Same api can be used both for reading local files or from disk.
# Separator parameter is used for delimiter, comma is default

# %%
local_file = 'titanic.csv'

# %%
df = pd.read_csv(local_file, sep=',')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
csv_file_online = 'https://raw.githubusercontent.com/datasets/population/master/data/population.csv'

# %%
df = pd.read_csv(csv_file_online, sep=',')

# %%
df
# Out:
#       Country Name Country Code  Year       Value
# 0            Aruba          ABW  1960     54922.0
# 1            Aruba          ABW  1961     55578.0
# 2            Aruba          ABW  1962     56320.0
# 3            Aruba          ABW  1963     57002.0
# 4            Aruba          ABW  1964     57619.0
# ...            ...          ...   ...         ...
# 16925     Zimbabwe          ZWE  2019  15271368.0
# 16926     Zimbabwe          ZWE  2020  15526888.0
# 16927     Zimbabwe          ZWE  2021  15797210.0
# 16928     Zimbabwe          ZWE  2022  16069056.0
# 16929     Zimbabwe          ZWE  2023  16340822.0
#
# [16930 rows x 4 columns]

# %% [markdown]
# **2.) Saving of dataframe to csv file**

# %% [markdown]
# You can decide wheather to save to dataframe with index or no

# %% [markdown]
# Important parameters:
#
# - sep, is the columns separator.
# - index , by default false, exports also index.
# - header , by default true, also exports column names as header.
# - columns, by default all, limit export to only certain columns.
# - mode, "w" is for write, "a" is for append.

# %%
# DataFrame
df = pd.DataFrame({
		'Name': ['Alice', 'Bob', 'Charlie'],
		'Age': [25, 30, 35],
		'Score': [85, 90, 95]
})


# Save to file
df.to_csv("data.csv", sep=',', index=False, header=True,  columns=['Name', 'Score'])

# %% [markdown]
# **You can also create compressed csv file in a zip fil**

# %%
compression_opts = dict(method='zip',
                        archive_name='out.csv')
df.to_csv('out.zip', index=False,
          compression=compression_opts)

# %% [markdown]
# # Indexing into dataframe

# %% [markdown]
# - .loc[]: Label-based selection.
# - .iloc[]: Position-based selection.
# - Boolean indexing: df[df['column'] > value]

# %%
	# DataFrame
df = pd.DataFrame({
		'Name': ['Alice', 'Bob', 'Charlie'],
		'Age': [25, 30, 35],
		'Score': [85, 90, 95]
  })

# %%
df
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     95

# %%
# Select column
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
# Filter rows
df[df['Score'] >= 90]
# Out:
#       Name  Age  Score
# 1      Bob   30     90
# 2  Charlie   35     95

# %%
# Select row by label
df.loc[1]
# Out:
# Name     Bob
# Age       30
# Score     90
# Name: 1, dtype: object

# %%
# Select row by position
df.iloc[2]
# Out:
# Name     Charlie
# Age           35
# Score         95
# Name: 2, dtype: object

# %%
type(df['Age']), type(df.iloc[2])
# Out:
# (pandas.core.series.Series, pandas.core.series.Series)

# %%
type(df[df['Score'] >= 99])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[df['Score'] >= 90])
# Out:
# pandas.core.frame.DataFrame
